# %% [markdown]
# ## 🚀 API Data Retrieval and JSON List Nesting

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
import requests

# %% [markdown]
# ### Retrieve Data from API using Requests

# %%
url = 'https://soda.demo.socrata.com/resource/6yvf-kk3n.json?source=pr&region=Virgin Islands region'

# %%
response = requests.get(url).json()

# %%
type(response)
# Out:
# list

# %% [markdown]
# #### json_normalize (max_level)

# %%
response[0:1]
# Out:
# [{'source': 'pr',
#   'earthquake_id': '12258002',
#   'version': '0',
#   'magnitude': '3.1',
#   'depth': '25',
#   'number_of_stations': '3',
#   'region': 'Virgin Islands region',
#   'location': {'type': 'Point', 'coordinates': [-64.3056, 19.6145]}}]

# %%
df_n1 = pd.json_normalize(response, max_level=1)
df_n1.head()
# Out:
#   source earthquake_id version magnitude depth number_of_stations  \
# 0     pr      12258002       0       3.1    25                  3
# 1     pr      12252002       0       3.1    43                  6
# 2     pr      12256005       0       3.1    47                  3
# 3     pr      12257002       0       3.1    43                  4
# 4     pr      12252005       0       3.3    60                  7
#
#                   region location.type location.coordinates
# 0  Virgin Islands region         Point  [-64.3056, 19.6145]
# 1  Virgin Islands region         Point   [-64.408, 19.6117]
# 2  Virgin Islands region         Point  [-63.8544, 19.3323]
# 3  Virgin Islands region         Point   [-64.568, 19.1303]
# 4  Virgin Islands region         Point    [-64.17, 19.6184]

# %%
lng = []
for i in range(len(df_n1.iloc[:, 8])):
    lng.append(df_n1.iloc[i, 8][0])

lat = []
for i in range(len(df_n1.iloc[:, 8])):
    lat.append(df_n1.iloc[i, 8][1])

# %%
df_n1["longitude"] = lng
df_n1["latitude"] = lat
print(len(df_n1))
df_n1.head()
# Out:
# 38
#   source earthquake_id version magnitude depth number_of_stations  \
# 0     pr      12258002       0       3.1    25                  3
# 1     pr      12252002       0       3.1    43                  6
# 2     pr      12256005       0       3.1    47                  3
# 3     pr      12257002       0       3.1    43                  4
# 4     pr      12252005       0       3.3    60                  7
#
#                   region location.type location.coordinates  longitude  \
# 0  Virgin Islands region         Point  [-64.3056, 19.6145]   -64.3056
# 1  Virgin Islands region         Point   [-64.408, 19.6117]   -64.4080
# 2  Virgin Islands region         Point  [-63.8544, 19.3323]   -63.8544
# 3  Virgin Islands region         Point   [-64.568, 19.1303]   -64.5680
# 4  Virgin Islands region         Point    [-64.17, 19.6184]   -64.1700
#
#    latitude
# 0   19.6145
# 1   19.6117
# 2   19.3323
# 3   19.1303
# 4   19.6184

# %% [markdown]
# #### json_normalize (record_path + manipulation)

# %%
response[0:1]
# Out:
# [{'source': 'pr',
#   'earthquake_id': '12258002',
#   'version': '0',
#   'magnitude': '3.1',
#   'depth': '25',
#   'number_of_stations': '3',
#   'region': 'Virgin Islands region',
#   'location': {'type': 'Point', 'coordinates': [-64.3056, 19.6145]}}]

# %%
df_n2 = pd.json_normalize(response, 
                           record_path=["location", "coordinates"],
                           meta=["depth", "earthquake_id", "magnitude", "number_of_stations",
                                 ["location", "type"], "source"]
                          )

df_n2.head()
# Out:
#          0 depth earthquake_id magnitude number_of_stations location.type  \
# 0 -64.3056    25      12258002       3.1                  3         Point
# 1  19.6145    25      12258002       3.1                  3         Point
# 2 -64.4080    43      12252002       3.1                  6         Point
# 3  19.6117    43      12252002       3.1                  6         Point
# 4 -63.8544    47      12256005       3.1                  3         Point
#
#   source
# 0     pr
# 1     pr
# 2     pr
# 3     pr
# 4     pr

# %%
df_n2.rename(columns={0 : "coordinates"}, inplace=True)

df_n2.head()
# Out:
#    coordinates depth earthquake_id magnitude number_of_stations location.type  \
# 0     -64.3056    25      12258002       3.1                  3         Point
# 1      19.6145    25      12258002       3.1                  3         Point
# 2     -64.4080    43      12252002       3.1                  6         Point
# 3      19.6117    43      12252002       3.1                  6         Point
# 4     -63.8544    47      12256005       3.1                  3         Point
#
#   source
# 0     pr
# 1     pr
# 2     pr
# 3     pr
# 4     pr

# %%
coord = df_n2.iloc[:,0]
print(len(coord))
coord.head()
# Out:
# 76
# 0   -64.3056
# 1    19.6145
# 2   -64.4080
# 3    19.6117
# 4   -63.8544
# Name: coordinates, dtype: float64

# %%
coord_lng = coord[0:len(coord):2]
coord_lat = coord[1:len(coord):2]

# %%
df_n2v2 = df_n2.drop("coordinates", axis = 1)
df_n2v2.head()
# Out:
#   depth earthquake_id magnitude number_of_stations location.type source
# 0    25      12258002       3.1                  3         Point     pr
# 1    25      12258002       3.1                  3         Point     pr
# 2    43      12252002       3.1                  6         Point     pr
# 3    43      12252002       3.1                  6         Point     pr
# 4    47      12256005       3.1                  3         Point     pr

# %%
df_n2v2 = df_n2v2.drop_duplicates().copy()
df_n2v2.head()
# Out:
#   depth earthquake_id magnitude number_of_stations location.type source
# 0    25      12258002       3.1                  3         Point     pr
# 2    43      12252002       3.1                  6         Point     pr
# 4    47      12256005       3.1                  3         Point     pr
# 6    43      12257002       3.1                  4         Point     pr
# 8    60      12252005       3.3                  7         Point     pr

# %%
df_n2v2.loc[:, "longitude"] = coord_lng

# %%
coord_lat = coord_lat.to_list()

# %%
df_n2v2.insert(6, 'latitude', coord_lat, True)

# %%
print(len(df_n2v2))
df_n2v2.head()
# Out:
# 38
#   depth earthquake_id magnitude number_of_stations location.type source  \
# 0    25      12258002       3.1                  3         Point     pr
# 2    43      12252002       3.1                  6         Point     pr
# 4    47      12256005       3.1                  3         Point     pr
# 6    43      12257002       3.1                  4         Point     pr
# 8    60      12252005       3.3                  7         Point     pr
#
#    latitude  longitude  latitude
# 0   19.6145   -64.3056       NaN
# 2   19.6117   -64.4080       NaN
# 4   19.3323   -63.8544       NaN
# 6   19.1303   -64.5680       NaN
# 8   19.6184   -64.1700       NaN

# %% [markdown]
# #### json_normalize (record_path)

# %%
data = [
    {
        "state": "Florida",
        "shortname": "FL",
        "info": {"governor": "Rick Scott"},
        "counties": [
            {"name": "Dade", "population": 12345},
            {"name": "Broward", "population": 40000},
            {"name": "Palm Beach", "population": 60000},
        ],
    },
    {
        "state": "Ohio",
        "shortname": "OH",
        "info": {"governor": "John Kasich"},
        "counties": [
            {"name": "Summit", "population": 1234},
            {"name": "Cuyahoga", "population": 1337},
        ],
    },
]

# %%
pd.json_normalize(data)
# Out:
#      state shortname                                           counties  \
# 0  Florida        FL  [{'name': 'Dade', 'population': 12345}, {'name...
# 1     Ohio        OH  [{'name': 'Summit', 'population': 1234}, {'nam...
#
#   info.governor
# 0    Rick Scott
# 1   John Kasich

# %%
pd.json_normalize(data, record_path=['counties'],
                 meta = ['state', 'shortname', ['info', 'governor']])
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich

# %% [markdown]
# ## Using nasted dataframe

# %%
df_n1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   source                38 non-null     object
#  1   earthquake_id         38 non-null     object
#  2   version               38 non-null     object
#  3   magnitude             38 non-null     object
#  4   depth                 38 non-null     object
#  5   number_of_stations    38 non-null     object
#  6   region                38 non-null     object
#  7   location.type         38 non-null     object
#  8   location.coordinates  38 non-null     object
#  9   longitude             38 non-null     float64
#  10  latitude              38 non-null     float64
# dtypes: float64(2), object(9)
# memory usage: 3.4+ KB

# %%
import folium

df_n1['magnitude'] = df_n1['magnitude'].astype(float)
magnitude_mean = df_n1['magnitude'].mean()

map_center = [df_n1['latitude'].mean(), df_n1['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=5)

def color_marker(magnitude):
    if magnitude < magnitude_mean:
        return 'green'
    else:
        return 'red'

for index, row in df_n1.iterrows():
    magnitude = row['magnitude']
    color = color_marker(magnitude)
    
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Magnitude: {magnitude}",
        icon=folium.Icon(color=color)
    ).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad0564b5a38fc672634aca294854085a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad0564b5a38fc672634aca294854085a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad0564b5a38fc672634aca294854085a = L.map(
#                 &quot;map_ad0564b5a38fc672634aca294854085a&quot;,
#                 {
#                     center: [19.446336842105257, -64.3104657894737],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_58f257cbd48175119dda5606b4ab2186 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ad0564b5a38fc672634aca294854085a);
#
#
#             var marker_9b2a35d498cdf7daccd9e69ae04b28f4 = L.marker(
#                 [19.6145, -64.3056],
#                 {}
#             ).addTo(map_ad0564b5a38fc672634aca294854085a);
#
#
#             var icon_855458b08de9992752267b8cf498a77a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b2a35d498cdf7daccd9e69ae04b28f4.setIcon(icon_855458b08de9992752267b8cf498a77a);
#
#
#         var popup_07e5d6fe888ae6c9c33f715ce093fd7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dcb4ee81d2536a48220cc944ed007a72 = $(`&lt;div id=&quot;html_dcb4ee81d2536a48220cc944ed007a72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 3.1&lt;/div&gt;`)[0];
#                 popup_07e5d6fe888ae6c9c33f715ce093fd7f.setContent(html_dcb4ee81d2536a48220cc944ed007a72);
#
#
#
#         marker_9b2a35d498cdf7daccd9e69ae04b28f4.bindPopup(popup_07e5d6fe888ae6c9c33f715ce093fd7f)
#         ;
#
#
#
#
#             var marker_14531b7a1bdd30160ee83ec73649b3f0 = L.marker(
#                 [19.6117, -64.408],
#                 {}
#             ).addTo(map_ad0564b5a38fc672634aca294854085a);
#
#
#             var icon_c7a4caa88b1700b24bf80f408377bb49 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_14531b7a1bdd30160ee83ec73649b3f0.setIcon(icon_c7a4caa88b1700b24bf80f408377bb49);
#
#
#         var popup_e9832b19a89d62754a4ff5d2b9fb0256 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4652efa37acf27795c1fd52bc642d72e = $(`&lt;div id=&quot;html_4652efa37acf27795c1fd52bc642d72e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 3.1&lt;/div&gt;`)[0];
#                 popup_e9832b19a89d62754a4ff5d2b9fb0256.setContent(html_4652efa37acf27795c1fd52bc642d72e);
#
#
#
#         marker_14531b7a1bdd30160ee83ec73649b3f0.bindPopup(popup_e9832b19a89d62754a4ff5d2b9fb0256)
#         ;
#
#
#
#
#             var marker_5f3fbd8b46daecf0e1166f19b653da04 = L.marker(
#                 [19.3323, -63.8544],
#                 {}
#             ).addTo(map_ad0564b5a38fc672634aca294854085a);
#
#
#             var icon_1228e9655b1481b8c51b67bd003f4416 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5f3fbd8b46daecf0e1166f19b653da04.setIcon(icon_1228e9655b1481b8c51b67bd003f4416);
#
#
#         var popup_e7b9c7e90a38e2b189c3b030e5d8abdf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7574d52108636a6de3fa66f1d4a3ddc6 = $(`&lt;div id=&quot;html_7574d52108636a6de3fa66f1d4a3ddc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Magnitude: 3.1&lt;/div&gt;`)[0];
#                 popup_e7b9c7e90a38e2b189c3b030e5d8abdf.setContent(html_7574d52108636a6de3fa66f1d4a3ddc6);
#
#
#
#         marker_5f3fbd8b46daecf0e1166f19b653da04.bindPopup(popup_e7b9c7e90a38e2b189c3b030e5d8abdf)
#         ;
#
#
#
#
#             var marker_52b0e9b66584ae95587f8747bebefa93 = L.marker(
#                 [19.1303, -64.568],
#                 {}
#             ).addTo(map_ad0564b5a38fc672634aca294854085a);
#
#
#             var icon_0d8e4bdb0a89290c976eacbab551825f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:
